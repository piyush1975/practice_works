# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
ipl = pd.read_csv("C:/Users/HP/OneDrive/Desktop/piyush/python_csv_files/cricket/info.csv")

# %%
ipl
# Out:
#           File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0      710305.csv    Bangladesh          326               3   Pakistan
# 1      667889.csv       England          247               6  Sri Lanka
# 2     1073420.csv      Pakistan           91              10   Scotland
# 3      749547.csv        Jersey          185              10       Oman
# 4      463154.csv  South Africa          250               9      India
# ...           ...           ...          ...             ...        ...
# 1664   236358.csv     Australia          274               8  Sri Lanka
# 1665   520593.csv   New Zealand          372               6   Zimbabwe
# 1666   247476.csv         India          254               6  Sri Lanka
# 1667   387567.csv  South Africa          354               6    England
# 1668   238188.csv         India          203              10    England
#
#       Team 2 Runs  Team 2 Wickets  Gender   Season        Date  ...  \
# ...

# %%
ipl.head()
# Out:
#        File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0   710305.csv    Bangladesh          326               3   Pakistan
# 1   667889.csv       England          247               6  Sri Lanka
# 2  1073420.csv      Pakistan           91              10   Scotland
# 3   749547.csv        Jersey          185              10       Oman
# 4   463154.csv  South Africa          250               9      India
#
#    Team 2 Runs  Team 2 Wickets  Gender   Season       Date  ...  \
# 0          329               7    male  2013/14   3/4/2014  ...
# 1          144              10    male     2014  5/22/2014  ...
# 2           94               4  female  2016/17  2/13/2017  ...
# 3          189               3    male     2014  6/22/2014  ...
# 4          234              10    male  2010/11  1/23/2011  ...
#
#              Umpire 1       Umpire 2    Reserve Umpire  TV Umpire  \
# 0           JD Cloete       NJ Llong      Tanvir Ahmed  CK Nandan
# ...

# %%
ipl.shape
# Out:
# (1669, 29)

# %%
ipl['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# AB de Villiers    25
# V Kohli           24
# TM Dilshan        23
# KC Sangakkara     22
# MS Dhoni          18
#                   ..
# PADLR Sandakan     1
# L Ronchi           1
# DM Kimmince        1
# DM de Silva        1
# E Otieno           1
# Name: count, Length: 554, dtype: int64

# %%
ipl['Player_of_Match'].value_counts()[0:10]
# Out:
# Player_of_Match
# AB de Villiers     25
# V Kohli            24
# TM Dilshan         23
# KC Sangakkara      22
# MS Dhoni           18
# Shahid Afridi      17
# Yuvraj Singh       16
# Shakib Al Hasan    15
# Mohammad Hafeez    15
# HM Amla            15
# Name: count, dtype: int64

# %%
ipl['Player_of_Match'].value_counts()[0:5]
# Out:
# Player_of_Match
# AB de Villiers    25
# V Kohli           24
# TM Dilshan        23
# KC Sangakkara     22
# MS Dhoni          18
# Name: count, dtype: int64

# %%
list(ipl['Player_of_Match'].value_counts()[0:5].keys())
# Out:
# ['AB de Villiers', 'V Kohli', 'TM Dilshan', 'KC Sangakkara', 'MS Dhoni']

# %%
plt.figure(figsize=(8,5))
plt.bar(list(ipl['Player_of_Match'].value_counts()[0:5].keys()),ipl['Player_of_Match'].value_counts()[0:5],color='g')
plt.show()

# %%
ipl['Toss_Winner'].value_counts()
# Out:
# Toss_Winner
# Sri Lanka                   165
# India                       164
# Australia                   160
# England                     159
# South Africa                148
# Pakistan                    135
# New Zealand                 119
# West Indies                 113
# Zimbabwe                     96
# Bangladesh                   95
# Ireland                      41
# Afghanistan                  34
# Netherlands                  18
# Canada                       17
# Scotland                     16
# United Arab Emirates         15
# Kenya                        15
# Nepal                        14
# Singapore                    10
# Oman                          9
# Malaysia                      8
# Denmark                       8
# Papua New Guinea              8
# Bermuda                       8
# Jersey                        8
# United States of America      8
# Italy                         8
# Namibia                       7
# Uganda                        7
# ...

# %%
ipl['Toss_Winner'].value_counts()[0:10]
# Out:
# Toss_Winner
# Sri Lanka       165
# India           164
# Australia       160
# England         159
# South Africa    148
# Pakistan        135
# New Zealand     119
# West Indies     113
# Zimbabwe         96
# Bangladesh       95
# Name: count, dtype: int64

# %%
ipl['Toss_Winner'].value_counts().keys()[0:5]
# Out:
# Index(['Sri Lanka', 'India', 'Australia', 'England', 'South Africa'], dtype='object', name='Toss_Winner')

# %%
plt.figure(figsize=(8,5))
plt.bar(list(ipl['Toss_Winner'].value_counts().keys()[0:5]),ipl['Toss_Winner'].value_counts()[0:5],color='r')
plt.show()

# %%
ipl['Winner_Runs'].value_counts()
# Out:
# Winner_Runs
# 5.0      15
# 20.0     12
# 1.0      12
# 34.0     12
# 21.0     11
#          ..
# 178.0     1
# 214.0     1
# 201.0     1
# 132.0     1
# 275.0     1
# Name: count, Length: 202, dtype: int64

# %%
batting_first = ipl[ipl['Winner_Runs']!=0]

# %%
batting_first
# Out:
#           File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0      710305.csv    Bangladesh          326               3   Pakistan
# 1      667889.csv       England          247               6  Sri Lanka
# 2     1073420.csv      Pakistan           91              10   Scotland
# 3      749547.csv        Jersey          185              10       Oman
# 4      463154.csv  South Africa          250               9      India
# ...           ...           ...          ...             ...        ...
# 1664   236358.csv     Australia          274               8  Sri Lanka
# 1665   520593.csv   New Zealand          372               6   Zimbabwe
# 1666   247476.csv         India          254               6  Sri Lanka
# 1667   387567.csv  South Africa          354               6    England
# 1668   238188.csv         India          203              10    England
#
#       Team 2 Runs  Team 2 Wickets  Gender   Season        Date  ...  \
# ...

# %%
batting_first.head()
# Out:
#        File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0   710305.csv    Bangladesh          326               3   Pakistan
# 1   667889.csv       England          247               6  Sri Lanka
# 2  1073420.csv      Pakistan           91              10   Scotland
# 3   749547.csv        Jersey          185              10       Oman
# 4   463154.csv  South Africa          250               9      India
#
#    Team 2 Runs  Team 2 Wickets  Gender   Season       Date  ...  \
# 0          329               7    male  2013/14   3/4/2014  ...
# 1          144              10    male     2014  5/22/2014  ...
# 2           94               4  female  2016/17  2/13/2017  ...
# 3          189               3    male     2014  6/22/2014  ...
# 4          234              10    male  2010/11  1/23/2011  ...
#
#              Umpire 1       Umpire 2    Reserve Umpire  TV Umpire  \
# 0           JD Cloete       NJ Llong      Tanvir Ahmed  CK Nandan
# ...

# %%
batting_first.dropna()
# Out:
# Empty DataFrame
# Columns: [File No, Team 1, Team 1 Runs, Team 1 Wickets, Team 2, Team 2 Runs, Team 2 Wickets, Gender, Season, Date, Series, Competition, Match Number, Venue, City, Neutral Venue, Toss_Winner, Toss_Decision, Player_of_Match, Umpire 1, Umpire 2, Reserve Umpire, TV Umpire, Match Referee, Winner, Outcome, Winner_Runs, Winner_Wickets, Method]
# Index: []
#
# [0 rows x 29 columns]

# %%
batting_first
# Out:
#           File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0      710305.csv    Bangladesh          326               3   Pakistan
# 1      667889.csv       England          247               6  Sri Lanka
# 2     1073420.csv      Pakistan           91              10   Scotland
# 3      749547.csv        Jersey          185              10       Oman
# 4      463154.csv  South Africa          250               9      India
# ...           ...           ...          ...             ...        ...
# 1664   236358.csv     Australia          274               8  Sri Lanka
# 1665   520593.csv   New Zealand          372               6   Zimbabwe
# 1666   247476.csv         India          254               6  Sri Lanka
# 1667   387567.csv  South Africa          354               6    England
# 1668   238188.csv         India          203              10    England
#
#       Team 2 Runs  Team 2 Wickets  Gender   Season        Date  ...  \
# ...

# %%
batting_first
# Out:
#           File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0      710305.csv    Bangladesh          326               3   Pakistan
# 1      667889.csv       England          247               6  Sri Lanka
# 2     1073420.csv      Pakistan           91              10   Scotland
# 3      749547.csv        Jersey          185              10       Oman
# 4      463154.csv  South Africa          250               9      India
# ...           ...           ...          ...             ...        ...
# 1664   236358.csv     Australia          274               8  Sri Lanka
# 1665   520593.csv   New Zealand          372               6   Zimbabwe
# 1666   247476.csv         India          254               6  Sri Lanka
# 1667   387567.csv  South Africa          354               6    England
# 1668   238188.csv         India          203              10    England
#
#       Team 2 Runs  Team 2 Wickets  Gender   Season        Date  ...  \
# ...

# %%
ipl = pd.read_csv("C:/Users/HP/OneDrive/Desktop/piyush/python_csv_files/cricket/info.csv")

# %%
ipl
# Out:
#           File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0      710305.csv    Bangladesh          326               3   Pakistan
# 1      667889.csv       England          247               6  Sri Lanka
# 2     1073420.csv      Pakistan           91              10   Scotland
# 3      749547.csv        Jersey          185              10       Oman
# 4      463154.csv  South Africa          250               9      India
# ...           ...           ...          ...             ...        ...
# 1664   236358.csv     Australia          274               8  Sri Lanka
# 1665   520593.csv   New Zealand          372               6   Zimbabwe
# 1666   247476.csv         India          254               6  Sri Lanka
# 1667   387567.csv  South Africa          354               6    England
# 1668   238188.csv         India          203              10    England
#
#       Team 2 Runs  Team 2 Wickets  Gender   Season        Date  ...  \
# ...

# %%
ipl['Winner_Runs'].dropna()
# Out:
# 1        81.0
# 4        33.0
# 6        48.0
# 8        46.0
# 13      117.0
#         ...
# 1664     22.0
# 1665    141.0
# 1666     69.0
# 1667    112.0
# 1668     39.0
# Name: Winner_Runs, Length: 808, dtype: float64

# %%
ipl['Winner_Runs'].dropna()
# Out:
# 1        81.0
# 4        33.0
# 6        48.0
# 8        46.0
# 13      117.0
#         ...
# 1664     22.0
# 1665    141.0
# 1666     69.0
# 1667    112.0
# 1668     39.0
# Name: Winner_Runs, Length: 808, dtype: float64

# %%
ipl.head()
# Out:
#        File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0   710305.csv    Bangladesh          326               3   Pakistan
# 1   667889.csv       England          247               6  Sri Lanka
# 2  1073420.csv      Pakistan           91              10   Scotland
# 3   749547.csv        Jersey          185              10       Oman
# 4   463154.csv  South Africa          250               9      India
#
#    Team 2 Runs  Team 2 Wickets  Gender   Season       Date  ...  \
# 0          329               7    male  2013/14   3/4/2014  ...
# 1          144              10    male     2014  5/22/2014  ...
# 2           94               4  female  2016/17  2/13/2017  ...
# 3          189               3    male     2014  6/22/2014  ...
# 4          234              10    male  2010/11  1/23/2011  ...
#
#              Umpire 1       Umpire 2    Reserve Umpire  TV Umpire  \
# 0           JD Cloete       NJ Llong      Tanvir Ahmed  CK Nandan
# ...

# %%
ipl
# Out:
#           File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0      710305.csv    Bangladesh          326               3   Pakistan
# 1      667889.csv       England          247               6  Sri Lanka
# 2     1073420.csv      Pakistan           91              10   Scotland
# 3      749547.csv        Jersey          185              10       Oman
# 4      463154.csv  South Africa          250               9      India
# ...           ...           ...          ...             ...        ...
# 1664   236358.csv     Australia          274               8  Sri Lanka
# 1665   520593.csv   New Zealand          372               6   Zimbabwe
# 1666   247476.csv         India          254               6  Sri Lanka
# 1667   387567.csv  South Africa          354               6    England
# 1668   238188.csv         India          203              10    England
#
#       Team 2 Runs  Team 2 Wickets  Gender   Season        Date  ...  \
# ...

# %%
dr = ipl['Winner_Runs'].dropna()

# %%
dr
# Out:
# 1        81.0
# 4        33.0
# 6        48.0
# 8        46.0
# 13      117.0
#         ...
# 1664     22.0
# 1665    141.0
# 1666     69.0
# 1667    112.0
# 1668     39.0
# Name: Winner_Runs, Length: 808, dtype: float64

# %%
dr.head()
# Out:
# 1      81.0
# 4      33.0
# 6      48.0
# 8      46.0
# 13    117.0
# Name: Winner_Runs, dtype: float64

# %%
plt.figure(figsize=(5,5))
plt.hist(dr)
plt.title('Distrubution of Runs')
plt.xlabel('Runs')
plt.show()

# %%
ipl['Winner'].value_counts()
# Out:
# Winner
# Australia                   216
# India                       198
# South Africa                170
# England                     161
# Sri Lanka                   157
# Pakistan                    133
# New Zealand                 128
# West Indies                  84
# Bangladesh                   79
# Zimbabwe                     40
# Ireland                      31
# Afghanistan                  27
# Nepal                        20
# Scotland                     15
# Oman                         13
# Netherlands                  12
# Kenya                        12
# Malaysia                     10
# Singapore                    10
# United States of America      9
# Denmark                       9
# United Arab Emirates          7
# Canada                        7
# Papua New Guinea              7
# Jersey                        7
# Hong Kong                     6
# Guernsey                      5
# Namibia                       5
# Uganda                        5
# ...

# %%
ipl['Winner'].value_counts()[0:5]
# Out:
# Winner
# Australia       216
# India           198
# South Africa    170
# England         161
# Sri Lanka       157
# Name: count, dtype: int64

# %%
list(ipl['Winner'].value_counts()[0:5].keys())
# Out:
# ['Australia', 'India', 'South Africa', 'England', 'Sri Lanka']

# %%
plt.figure(figsize=(5,5))
plt.bar(list(ipl['Winner'].value_counts()[0:5].keys()),ipl['Winner'].value_counts()[0:5],color =['g','y','r','blue','black'])
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.pie(list(ipl['Winner'].value_counts()[0:5]),labels=list(ipl['Winner'].value_counts()[0:5].keys()),autopct='%0.1f%%')
plt.show()

# %%
ipl
# Out:
#           File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0      710305.csv    Bangladesh          326               3   Pakistan
# 1      667889.csv       England          247               6  Sri Lanka
# 2     1073420.csv      Pakistan           91              10   Scotland
# 3      749547.csv        Jersey          185              10       Oman
# 4      463154.csv  South Africa          250               9      India
# ...           ...           ...          ...             ...        ...
# 1664   236358.csv     Australia          274               8  Sri Lanka
# 1665   520593.csv   New Zealand          372               6   Zimbabwe
# 1666   247476.csv         India          254               6  Sri Lanka
# 1667   387567.csv  South Africa          354               6    England
# 1668   238188.csv         India          203              10    England
#
#       Team 2 Runs  Team 2 Wickets  Gender   Season        Date  ...  \
# ...

# %%
ipl['Winner_Wickets'].dropna()
# Out:
# 0       3.0
# 2       6.0
# 3       7.0
# 5       5.0
# 7       6.0
#        ...
# 1656    3.0
# 1657    5.0
# 1658    4.0
# 1659    8.0
# 1663    7.0
# Name: Winner_Wickets, Length: 822, dtype: float64

# %%
bating_wik = ipl[ipl['Winner_Wickets']!=0]

# %%
bating_wik.head()
# Out:
#        File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0   710305.csv    Bangladesh          326               3   Pakistan
# 1   667889.csv       England          247               6  Sri Lanka
# 2  1073420.csv      Pakistan           91              10   Scotland
# 3   749547.csv        Jersey          185              10       Oman
# 4   463154.csv  South Africa          250               9      India
#
#    Team 2 Runs  Team 2 Wickets  Gender   Season       Date  ...  \
# 0          329               7    male  2013/14   3/4/2014  ...
# 1          144              10    male     2014  5/22/2014  ...
# 2           94               4  female  2016/17  2/13/2017  ...
# 3          189               3    male     2014  6/22/2014  ...
# 4          234              10    male  2010/11  1/23/2011  ...
#
#              Umpire 1       Umpire 2    Reserve Umpire  TV Umpire  \
# 0           JD Cloete       NJ Llong      Tanvir Ahmed  CK Nandan
# ...

# %%
bating_wik
# Out:
# Winner_Wickets
# 6.0     145
# 7.0     141
# 8.0     106
# 5.0     102
# 4.0     100
# 3.0      77
# 9.0      52
# 2.0      46
# 1.0      33
# 10.0     20
# Name: count, dtype: int64

# %%
bating_wik.head()
# Out:
# Winner_Wickets
# 6.0    145
# 7.0    141
# 8.0    106
# 5.0    102
# 4.0    100
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.hist(bating_wik['Winner_Wickets'],bins = 30)
plt.title('Matches of winner team by wickets')
plt.xlabel('Winner Wikets of Team')
plt.ylabel('Matches')
plt.show()

# %%
bat_wik_win =list(bating_wik['Winner'].value_counts()[0:5])

# %%
bat_wik_win =list(bating_wik['Winner'].value_counts()[0:5].keys())

# %%
bat_wik_win
# Out:
# ['Australia', 'India', 'South Africa', 'England', 'Sri Lanka']

# %%
plt.figure(figsize=(5,5))
plt.bar(list(bating_wik['Winner'].value_counts()[0:5].keys()),list(bating_wik['Winner'].value_counts()[0:5]))
plt.show()

# %%
ipl
# Out:
#           File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0      710305.csv    Bangladesh          326               3   Pakistan
# 1      667889.csv       England          247               6  Sri Lanka
# 2     1073420.csv      Pakistan           91              10   Scotland
# 3      749547.csv        Jersey          185              10       Oman
# 4      463154.csv  South Africa          250               9      India
# ...           ...           ...          ...             ...        ...
# 1664   236358.csv     Australia          274               8  Sri Lanka
# 1665   520593.csv   New Zealand          372               6   Zimbabwe
# 1666   247476.csv         India          254               6  Sri Lanka
# 1667   387567.csv  South Africa          354               6    England
# 1668   238188.csv         India          203              10    England
#
#       Team 2 Runs  Team 2 Wickets  Gender   Season        Date  ...  \
# ...

# %%
ipl['Season'].value_counts()
# Out:
# Season
# 2014/15    145
# 2016/17    142
# 2006/07    117
# 2017        95
# 2010/11     91
# 2013/14     78
# 2011/12     75
# 2007/08     73
# 2014        73
# 2009/10     73
# 2013        69
# 2015/16     64
# 2012/13     57
# 2015        54
# 2016        53
# 2010        52
# 2019        51
# 2008/09     49
# 2012        47
# 2005/06     45
# 2008        40
# 2009        39
# 2011        38
# 2007        27
# 2006        22
# Name: count, dtype: int64

# %%
macthes_yr = ipl['Season'].value_counts()

# %%
macthes_yr
# Out:
# Season
# 2014/15    145
# 2016/17    142
# 2006/07    117
# 2017        95
# 2010/11     91
# 2013/14     78
# 2011/12     75
# 2007/08     73
# 2014        73
# 2009/10     73
# 2013        69
# 2015/16     64
# 2012/13     57
# 2015        54
# 2016        53
# 2010        52
# 2019        51
# 2008/09     49
# 2012        47
# 2005/06     45
# 2008        40
# 2009        39
# 2011        38
# 2007        27
# 2006        22
# Name: count, dtype: int64

# %%
macthes_yr.head()
# Out:
# Season
# 2014/15    145
# 2016/17    142
# 2006/07    117
# 2017        95
# 2010/11     91
# Name: count, dtype: int64

# %%
ipl['City'].value_counts()
# Out:
# City
# Mirpur                84
# Colombo               77
# London                57
# Kuala Lumpur          48
# Abu Dhabi             33
#                       ..
# Toronto                1
# Wormsley               1
# Bishop's Stortford     1
# Jamshedpur             1
# Whangarei              1
# Name: count, Length: 137, dtype: int64

# %%
city_macthes = ipl['City'].value_counts()

# %%
city_macthes.head()
# Out:
# City
# Mirpur          84
# Colombo         77
# London          57
# Kuala Lumpur    48
# Abu Dhabi       33
# Name: count, dtype: int64

# %%
import numpy as np
np.sum(ipl['Toss_Winner']==ipl['Winner'])
# Out:
# np.int64(814)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 4
#       2 import numpy as np
#       3 import seaborn as sns
# ----> 4 from sklearn.model_selection import train_test_split
#       5 from sklearn.linear_model import LinearRegression
#       6 import statsmodels.api as sm
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
data= pd.read_csv("C:/Users/HP/OneDrive/Desktop/piyush/python_csv_files/cricket/data.csv")
data
# Out:
#           File No      Player Name  Innings  Batting Position  Runs  Dots  1s  \
# 0      710305.csv     Anamul Haque        1               1.0   100    74  46
# 1      710305.csv      Imrul Kayes        1               2.0    59    44  27
# 2      710305.csv    Mominul Haque        1               3.0    51    17  21
# 3      710305.csv  Mushfiqur Rahim        1               4.0    51     9  17
# 4      710305.csv  Shakib Al Hasan        1               5.0    44     2   6
# ...           ...              ...      ...               ...   ...   ...  ..
# 35823  238188.csv         GO Jones        2               7.0     0    10   0
# 35824  238188.csv     ID Blackwell        2               8.0    10    16   2
# 35825  238188.csv      LE Plunkett        2               9.0    14    23   6
# 35826  238188.csv        Kabir Ali        2              10.0     0     6   0
# 35827  238188.csv      JM Anderson        2              11.0    12    11   4
#
# ...

# %%
data
# Out:
#           File No      Player Name  Innings  Batting Position  Runs  Dots  1s  \
# 0      710305.csv     Anamul Haque        1               1.0   100    74  46
# 1      710305.csv      Imrul Kayes        1               2.0    59    44  27
# 2      710305.csv    Mominul Haque        1               3.0    51    17  21
# 3      710305.csv  Mushfiqur Rahim        1               4.0    51     9  17
# 4      710305.csv  Shakib Al Hasan        1               5.0    44     2   6
# ...           ...              ...      ...               ...   ...   ...  ..
# 35823  238188.csv         GO Jones        2               7.0     0    10   0
# 35824  238188.csv     ID Blackwell        2               8.0    10    16   2
# 35825  238188.csv      LE Plunkett        2               9.0    14    23   6
# 35826  238188.csv        Kabir Ali        2              10.0     0     6   0
# 35827  238188.csv      JM Anderson        2              11.0    12    11   4
#
# ...

# %%
data=data[['File No','Runs','4s','6s','Balls Played','Dots']]

# %%
data
# Out:
#           File No  Runs  4s  6s  Balls Played  Dots
# 0      710305.csv   100   6   4           133    74
# 1      710305.csv    59   5   2            78    44
# 2      710305.csv    51   6   0            47    17
# 3      710305.csv    51   8   0            35     9
# 4      710305.csv    44   6   2            17     2
# ...           ...   ...  ..  ..           ...   ...
# 35823  238188.csv     0   0   0            10    10
# 35824  238188.csv    10   2   0            20    16
# 35825  238188.csv    14   2   0            31    23
# 35826  238188.csv     0   0   0             6     6
# 35827  238188.csv    12   2   0            17    11
#
# [35828 rows x 6 columns]

# %%
data.head()
# Out:
#       File No  Runs  4s  6s  Balls Played  Dots
# 0  710305.csv   100   6   4           133    74
# 1  710305.csv    59   5   2            78    44
# 2  710305.csv    51   6   0            47    17
# 3  710305.csv    51   8   0            35     9
# 4  710305.csv    44   6   2            17     2

# %%
data= pd.read_csv("C:/Users/HP/OneDrive/Desktop/piyush/python_csv_files/cricket/data.csv")
data
# Out:
#           File No      Player_Name  Innings  Batting_Position  Runs  Dots  1s  \
# 0      710305.csv     Anamul Haque        1               1.0   100    74  46
# 1      710305.csv      Imrul Kayes        1               2.0    59    44  27
# 2      710305.csv    Mominul Haque        1               3.0    51    17  21
# 3      710305.csv  Mushfiqur Rahim        1               4.0    51     9  17
# 4      710305.csv  Shakib Al Hasan        1               5.0    44     2   6
# ...           ...              ...      ...               ...   ...   ...  ..
# 35823  238188.csv         GO Jones        2               7.0     0    10   0
# 35824  238188.csv     ID Blackwell        2               8.0    10    16   2
# 35825  238188.csv      LE Plunkett        2               9.0    14    23   6
# 35826  238188.csv        Kabir Ali        2              10.0     0     6   0
# 35827  238188.csv      JM Anderson        2              11.0    12    11   4
#
# ...

# %%
data['Innings'].unique()
# Out:
# array([1, 2])

# %%
match_1 = data[data['Innings']==1]

# %%
match_1.shape
# Out:
# (18218, 17)

# %%
match_1
# Out:
#           File No      Player_Name  Innings  Batting_Position  Runs  Dots  1s  \
# 0      710305.csv     Anamul Haque        1               1.0   100    74  46
# 1      710305.csv      Imrul Kayes        1               2.0    59    44  27
# 2      710305.csv    Mominul Haque        1               3.0    51    17  21
# 3      710305.csv  Mushfiqur Rahim        1               4.0    51     9  17
# 4      710305.csv  Shakib Al Hasan        1               5.0    44     2   6
# ...           ...              ...      ...               ...   ...   ...  ..
# 35812  238188.csv        IK Pathan        1               7.0    28    32   8
# 35813  238188.csv         MS Dhoni        1               8.0    20    16  10
# 35814  238188.csv  Harbhajan Singh        1               9.0    37    27  13
# 35815  238188.csv         RP Singh        1              10.0     2     1   2
# 35816  238188.csv      S Sreesanth        1              11.0     0     1   0
#
# ...

# %%
match_1['Runs_Given'].value_counts()
# Out:
# Runs_Given
# 0      8121
# 29      277
# 31      272
# 25      254
# 30      248
#        ...
# 82        1
# 101       1
# 89        1
# 86        1
# 84        1
# Name: count, Length: 90, dtype: int64

# %%
import pandas as pd
data= pd.read_csv("C:/Users/HP/OneDrive/Desktop/piyush/python_csv_files/cricket/data.csv")
data
# Out:
#           File No      Player_Name  Innings  Batting_Position  Runs  Dots  1s  \
# 0      710305.csv     Anamul Haque        1               1.0   100    74  46
# 1      710305.csv      Imrul Kayes        1               2.0    59    44  27
# 2      710305.csv    Mominul Haque        1               3.0    51    17  21
# 3      710305.csv  Mushfiqur Rahim        1               4.0    51     9  17
# 4      710305.csv  Shakib Al Hasan        1               5.0    44     2   6
# ...           ...              ...      ...               ...   ...   ...  ..
# 35823  238188.csv         GO Jones        2               7.0     0    10   0
# 35824  238188.csv     ID Blackwell        2               8.0    10    16   2
# 35825  238188.csv      LE Plunkett        2               9.0    14    23   6
# 35826  238188.csv        Kabir Ali        2              10.0     0     6   0
# 35827  238188.csv      JM Anderson        2              11.0    12    11   4
#
# ...

# %%
In2 = data[data['Innings']==2]

# %%
In2
# Out:
#           File No      Player_Name  Innings  Batting_Position  Runs  Dots  1s  \
# 10     710305.csv    Ahmed Shehzad        2               1.0   103    66  43
# 11     710305.csv  Mohammad Hafeez        2               2.0    52    33  12
# 12     710305.csv    Misbah-ul-Haq        2               3.0     4     3   0
# 13     710305.csv   Sohaib Maqsood        2               4.0     2     3   2
# 14     710305.csv       Fawad Alam        2               5.0    74    25  36
# ...           ...              ...      ...               ...   ...   ...  ..
# 35823  238188.csv         GO Jones        2               7.0     0    10   0
# 35824  238188.csv     ID Blackwell        2               8.0    10    16   2
# 35825  238188.csv      LE Plunkett        2               9.0    14    23   6
# 35826  238188.csv        Kabir Ali        2              10.0     0     6   0
# 35827  238188.csv      JM Anderson        2              11.0    12    11   4
#
# ...

# %%
In2.shape
# Out:
# (17610, 17)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data
# Out:
#           File No      Player_Name  Innings  Batting_Position  Runs  Dots  1s  \
# 0      710305.csv     Anamul Haque        1               1.0   100    74  46
# 1      710305.csv      Imrul Kayes        1               2.0    59    44  27
# 2      710305.csv    Mominul Haque        1               3.0    51    17  21
# 3      710305.csv  Mushfiqur Rahim        1               4.0    51     9  17
# 4      710305.csv  Shakib Al Hasan        1               5.0    44     2   6
# ...           ...              ...      ...               ...   ...   ...  ..
# 35823  238188.csv         GO Jones        2               7.0     0    10   0
# 35824  238188.csv     ID Blackwell        2               8.0    10    16   2
# 35825  238188.csv      LE Plunkett        2               9.0    14    23   6
# 35826  238188.csv        Kabir Ali        2              10.0     0     6   0
# 35827  238188.csv      JM Anderson        2              11.0    12    11   4
#
# ...

# %%
player_de = data[['Player_Name','Runs']]

# %%
player_de.head()
# Out:
#        Player_Name  Runs
# 0     Anamul Haque   100
# 1      Imrul Kayes    59
# 2    Mominul Haque    51
# 3  Mushfiqur Rahim    51
# 4  Shakib Al Hasan    44

# %%
player_de = player_de.sort_values(by=['Runs'],ascending=False)

# %%
player_de.head()
# Out:
#       Player_Name  Runs
# 17486   RG Sharma   264
# 18744  MJ Guptill   237
# 32664    V Sehwag   219
# 9037     CH Gayle   215
# 16114   RG Sharma   209

# %%
list(player_de['Player_Name'])[0:5]
# Out:
# ['RG Sharma', 'MJ Guptill', 'V Sehwag', 'CH Gayle', 'RG Sharma']

# %%
list(player_de['Runs'])[0:5]
# Out:
# [264, 237, 219, 215, 209]

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_de['Player_Name'])[0:5],list(player_de['Runs'])[0:5],color='g')
plt.show()
