# %%
import pandas as pd
import numpy as np

# %%
d1 = pd.read_csv('C:/Users/HP/OneDrive/Desktop/piyush/python_csv_files/fifa/players_20.csv')

# %%
data1 = pd.DataFrame(d1)

# %%
data1
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
X = data1.iloc[:,0:8]
y = data1.iloc[:,2]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=False)

# %%
num_cols = ['age','height_cm','weight_kg']
name_cols = ['short_name']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer

# %%
numeric_processer = Pipeline(steps = [
        ("imputation_mean",SimpleImputer(missing_values=np.nan,strategy="mean")),
    ("scaler",StandardScaler())
    
])

# %%
numeric_processer
# Out:
# Pipeline(steps=[('imputation_mean', SimpleImputer()),
#                 ('scaler', StandardScaler())])

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder
categorical_processer = Pipeline(steps = [
        ("imputation_constant",SimpleImputer(fill_value="missing",strategy="constant")),
        ("onehot",OneHotEncoder(handle_unknown="ignore"))
    ])

# %%
Combine_processor = ColumnTransformer([
    ('Name',categorical_processer,name_cols),
     ('Numerical',numeric_processer,num_cols )                             
      ])

# %%
Combine_processor
# Out:
# ColumnTransformer(transformers=[('Name',
#                                  Pipeline(steps=[('imputation_constant',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['short_name']),
#                                 ('Numerical',
#                                  Pipeline(steps=[('imputation_mean',
#                                                   SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['age', 'height_cm', 'weight_kg'])])

# %%
Combine_processor
# Out:
# ColumnTransformer(transformers=[('Name',
#                                  Pipeline(steps=[('imputation_constant',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['short_name']),
#                                 ('Numerical',
#                                  Pipeline(steps=[('imputation_mean',
#                                                   SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['age', 'height_cm', 'weight_kg'])])

# %%
from sklearn.pipeline import make_pipeline

# %%
final_pipe = make_pipeline(Combine_processor,LogisticRegression())

# %%
final_pipe

# %%
final_pipe.fit(X_train,y_train)
